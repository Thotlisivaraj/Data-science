# %% [markdown]
# <a href="https://colab.research.google.com/github/Thotlisivaraj/Data-science/blob/main/basics_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df.iloc[:,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-1240625856.py in <cell line: 0>()
# ----> 1 df.loc[:,:]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv('Salaries.csv')

# %%
df.set_option('display.max_columns',None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-6-1915066283.py in <cell line: 0>()
# ----> 1 df.set_option('display.max_columns',None)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'set_option'

# %%
imprt matplotlib.pyplot as PlainTextFormatter
# Out:
#   File "/tmp/ipython-input-7-3376615638.py", line 1
#     imprt matplotlib.pyplot as PlainTextFormatter
#           ^
# SyntaxError: invalid syntax

# %%
/content/Salaries.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-8-1342291153.py in <cell line: 0>()
# ----> 1 content/Salaries.csv()
#
# NameError: name 'content' is not defined

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['SAT'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-12-2464698917.py in <cell line: 0>()
# ----> 1 plt.hist(df1['SAT'])
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['SAT'])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df1['SAT'])
plt.show()

# %%
plt.plot(df1['SAT'],df1['Accept'],'bo')
plt.xlabel('SAT')
plt.ylabel('Accept')
plt.show()

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df.iloc[:,1:3])

# %%
plt.boxplot(df1['SAT'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78d6355f31d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78d6355f1a10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78d6355f2450>],
#  'medians': [<matplotlib.lines.Line2D at 0x78d633d36ed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78d633d86a10>],
#  'means': []}
